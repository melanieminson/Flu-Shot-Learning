# %% [markdown]
# <a href="https://colab.research.google.com/github/melanieminson/Flu-Shot-Learning/blob/main/Final_Project_DATA695.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # H1N1 and Seasonal Flu Vaccine Administration Data

# %% [markdown]
# ##Variable Explanation and Introduction

# %% [markdown]
# ###Define the Problem

# %% [markdown]
# For this dataset, there are two target variables:
# >
# **h1n1_vaccine** - Whether respondent received H1N1 flu vaccine.
# >
# **seasonal_vaccine** - Whether respondent received seasonal flu vaccine.
# >
# Both are binary variables: 0 = No; 1 = Yes. Some respondents didn't get either vaccine, others got only one, and some got both. This is formulated as a multilabel (and not multiclass) problem.

# %% [markdown]
# ###Data Dictionary

# %% [markdown]
# The first column respondent_id is a unique and random identifier. For all binary variables: 0 = No; 1 = Yes.
#
# **h1n1_concern** - Level of concern about the H1N1 flu.
# 0 = Not at all concerned; 1 = Not very concerned; 2 = Somewhat concerned; 3 = Very concerned.
# >
# **h1n1_knowledge** - Level of knowledge about H1N1 flu.
# 0 = No knowledge; 1 = A little knowledge; 2 = A lot of knowledge.
# >
# **behavioral_antiviral_meds** - Has taken antiviral medications. (binary)
# >
# **behavioral_avoidance** - Has avoided close contact with others with flu-like symptoms. (binary)
# behavioral_face_mask - Has bought a face mask. (binary)
# >
# **behavioral_wash_hands** - Has frequently washed hands or used hand sanitizer. (binary)
# >
# **behavioral_large_gatherings** - Has reduced time at large gatherings. (binary)
# >
# **behavioral_outside_home** - Has reduced contact with people outside of own household. (binary)
# >
# **behavioral_touch_face** - Has avoided touching eyes, nose, or mouth. (binary)
# >
# **doctor_recc_h1n1** - H1N1 flu vaccine was recommended by doctor. (binary)
# >
# **doctor_recc_seasonal** - Seasonal flu vaccine was recommended by doctor. (binary)
# >
# **chronic_med_condition** - Has any of the following chronic medical conditions: asthma or an other lung condition, diabetes, a heart condition, a kidney condition, sickle cell anemia or other anemia, a neurological or neuromuscular condition, a liver condition, or a weakened immune system caused by a chronic illness or by medicines taken for a chronic illness. (binary)
# >
# **child_under_6_months**- Has regular close contact with a child under the age of six months. (binary)
# >
# **health_worker**- Is a healthcare worker. (binary)
# >
# **health_insurance**- Has health insurance. (binary)
# >
# **opinion_h1n1_vacc_effective** - Respondent's opinion about H1N1 vaccine effectiveness.
# 1 = Not at all effective; 2 = Not very effective; 3 = Don't know; 4 = Somewhat effective; 5 = Very effective.
# >
# **opinion_h1n1_risk** - Respondent's opinion about risk of getting sick with H1N1 flu without vaccine.
# 1 = Very Low; 2 = Somewhat low; 3 = Don't know; 4 = Somewhat high; 5 = Very high.
# >
# **opinion_h1n1_sick_from_vacc** - Respondent's worry of getting sick from taking H1N1 vaccine.
# 1 = Not at all worried; 2 = Not very worried; 3 = Don't know; 4 = Somewhat worried; 5 = Very worried.
# >
# **opinion_seas_vacc_effective** - Respondent's opinion about seasonal flu vaccine effectiveness.
# 1 = Not at all effective; 2 = Not very effective; 3 = Don't know; 4 = Somewhat effective; 5 = Very effective.
# >
# **opinion_seas_risk** - Respondent's opinion about risk of getting sick with seasonal flu without vaccine.
# 1 = Very Low; 2 = Somewhat low; 3 = Don't know; 4 = Somewhat high; 5 = Very high.
# >
# **opinion_seas_sick_from_vacc** - Respondent's worry of getting sick from taking seasonal flu vaccine.
# 1 = Not at all worried; 2 = Not very worried; 3 = Don't know; 4 = Somewhat worried; 5 = Very worried.
# >
# **age_group** - Age group of respondent.
# >
# **education** - Self-reported education level.
# >
# **race** - Race of respondent.
# >
# **sex**- Sex of respondent.
# >
# **income_poverty** - Household annual income of respondent with respect to 2008 Census poverty thresholds.
# >
# **marital_status** - Marital status of respondent.
# >
# **rent_or_own** - Housing situation of respondent.
# >
# **employment_status**- Employment status of respondent.
# >
# **hhs_geo_region** - Respondent's residence using a 10-region geographic classification defined by the U.S. Dept. of Health and Human Services. Values are represented as short random character strings.
# >
# **census_msa** - Respondent's residence within metropolitan statistical areas (MSA) as defined by the U.S. Census.
# >
# **household_adults** - Number of other adults in household, top-coded to 3.
# >
# **household_children** - Number of children in household, top-coded to 3.
# >
# **employment_industry** - Type of industry respondent is employed in. Values are represented as short random character strings.
# >
# **employment_occupation** - Type of occupation of respondent. Values are represented as short random character strings.

# %% [markdown]
# ##Exploratory Data Analysis

# %% [markdown]
# ### Import Data and Explore Features

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/melanieminson/DATA695/main/training_set.csv')

# %%
df.shape
# Out:
# (26707, 38)

# %%
df.head()
# Out:
#    respondent_id  h1n1_concern  ...  h1n1_vaccine  seasonal_vaccine
# 0              0           1.0  ...             0                 0
# 1              1           3.0  ...             0                 1
# 2              2           1.0  ...             0                 0
# 3              3           1.0  ...             0                 1
# 4              4           2.0  ...             0                 0
#
# [5 rows x 38 columns]

# %%
df.dtypes
# Out:
# respondent_id                    int64
# h1n1_concern                   float64
# h1n1_knowledge                 float64
# behavioral_antiviral_meds      float64
# behavioral_avoidance           float64
# behavioral_face_mask           float64
# behavioral_wash_hands          float64
# behavioral_large_gatherings    float64
# behavioral_outside_home        float64
# behavioral_touch_face          float64
# doctor_recc_h1n1               float64
# doctor_recc_seasonal           float64
# chronic_med_condition          float64
# child_under_6_months           float64
# health_worker                  float64
# health_insurance               float64
# opinion_h1n1_vacc_effective    float64
# opinion_h1n1_risk              float64
# opinion_h1n1_sick_from_vacc    float64
# opinion_seas_vacc_effective    float64
# opinion_seas_risk              float64
# opinion_seas_sick_from_vacc    float64
# age_group                       object
# education                       object
# ...

# %%
df.isnull().sum()
# Out:
# respondent_id                      0
# h1n1_concern                      92
# h1n1_knowledge                   116
# behavioral_antiviral_meds         71
# behavioral_avoidance             208
# behavioral_face_mask              19
# behavioral_wash_hands             42
# behavioral_large_gatherings       87
# behavioral_outside_home           82
# behavioral_touch_face            128
# doctor_recc_h1n1                2160
# doctor_recc_seasonal            2160
# chronic_med_condition            971
# child_under_6_months             820
# health_worker                    804
# health_insurance               12274
# opinion_h1n1_vacc_effective      391
# opinion_h1n1_risk                388
# opinion_h1n1_sick_from_vacc      395
# opinion_seas_vacc_effective      462
# opinion_seas_risk                514
# opinion_seas_sick_from_vacc      537
# age_group                          0
# education                       1407
# race                               0
# ...

# %% [markdown]
# ### Target Variables

# %% [markdown]
# #### H1N1 Vaccine

# %%
df['h1n1_vaccine'].value_counts()
# Out:
# 0    21033
# 1     5674
# Name: h1n1_vaccine, dtype: int64

# %%
temp = df["h1n1_vaccine"].value_counts()
dfh1n1bal = pd.DataFrame({'h1n1_vaccine': temp.index,'values': temp.values})
plt.figure(figsize = (6,6))
sns.barplot(x = 'h1n1_vaccine', y="values", data=dfh1n1bal)
plt.show()

# %% [markdown]
# There is an huge gap between the amounts of people who got the H1N1 vaccine and those who didn't. There are almost four times more people who did not receive the H1N1 vaccine than those who did. We will need to rely on different metrics rather than the common average metrics.

# %% [markdown]
# #### Seasonal Flu Vaccine

# %%
df['seasonal_vaccine'].value_counts()
# Out:
# 0    14272
# 1    12435
# Name: seasonal_vaccine, dtype: int64

# %%
temp = df["seasonal_vaccine"].value_counts()
dfflubal = pd.DataFrame({'seasonal_vaccine': temp.index,'values': temp.values})
plt.figure(figsize = (6,6))
sns.barplot(x = 'seasonal_vaccine', y="values", data=dfflubal)
plt.show()

# %% [markdown]
# The number of people who received the flu shot is nearly as high as the number of people who didn't. This number is much more balanced than the difference in the H1N1 vaccine recipients.

# %% [markdown]
# ### Null Values

# %%
for column in df.columns:
    df[column].fillna(df[column].mode()[0], inplace=True)

# %%
df.shape
# Out:
# (26707, 38)

# %%
df.isnull().sum()
# Out:
# respondent_id                  0
# h1n1_concern                   0
# h1n1_knowledge                 0
# behavioral_antiviral_meds      0
# behavioral_avoidance           0
# behavioral_face_mask           0
# behavioral_wash_hands          0
# behavioral_large_gatherings    0
# behavioral_outside_home        0
# behavioral_touch_face          0
# doctor_recc_h1n1               0
# doctor_recc_seasonal           0
# chronic_med_condition          0
# child_under_6_months           0
# health_worker                  0
# health_insurance               0
# opinion_h1n1_vacc_effective    0
# opinion_h1n1_risk              0
# opinion_h1n1_sick_from_vacc    0
# opinion_seas_vacc_effective    0
# opinion_seas_risk              0
# opinion_seas_sick_from_vacc    0
# age_group                      0
# education                      0
# race                           0
# sex                            0
# income_poverty                 0
# marital_status                 0
# ...

# %% [markdown]
# The features with substantial null values are health_insurance, income_poverty, employment_industry, and employment_occupation. Just as an observation, I hypothesize that there is a collinearity between employment_industry and employment_occupation, since they are of similar nature.
#
# I will continue to run analysis without these variables. If I am not able to model accurately based on the remaining 32 features, I will reevaluate these to calculate appropriate replacement values for these four variables. However, since there are many other features, I will evaluate based on the features that do not have null values.

# %% [markdown]
# ### Feature Engineering for Variable Exploration

# %% [markdown]
# In this section, I will code variables that were previously of the type "object" into integer and will convert the categorical responses into numerical responses in an attempt to be able to use them in more intuitive ways.

# %%
#age_group
df.age_group[df.age_group == '18 - 34 Years'] = 1
df.age_group[df.age_group == '35 - 44 Years'] = 2
df.age_group[df.age_group == '45 - 54 Years'] = 3
df.age_group[df.age_group == '55 - 64 Years'] = 4
df.age_group[df.age_group == '65+ Years'] = 5

df.age_group = df.age_group.astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#education
df.education[df.education == '< 12 Years'] = 1
df.education[df.education == '12 Years'] = 2
df.education[df.education == 'College Graduate'] = 3
df.education[df.education == 'Some College'] = 4

df.education = df.education.astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#race
df.race[df.race == 'Black'] = 1
df.race[df.race == 'Hispanic'] = 2
df.race[df.race == 'Other or Multiple'] = 3
df.race[df.race == 'White'] = 4

df.race = df.race.astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#sex
df.sex[df.sex == 'Female'] = 0
df.sex[df.sex == 'Male'] = 1

df.sex = df.sex.astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#marital_status
df.marital_status[df.marital_status == 'Married'] = 0
df.marital_status[df.marital_status == 'Not Married'] = 1

df.marital_status = df.marital_status.astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#rent_or_own
df.rent_or_own[df.rent_or_own == 'Rent'] = 0
df.rent_or_own[df.rent_or_own == 'Own'] = 1

df.rent_or_own = df.rent_or_own.astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#employment_status
df.employment_status[df.employment_status == 'Employed'] = 1
df.employment_status[df.employment_status == 'Not in Labor Force'] = 2
df.employment_status[df.employment_status == 'Unemployed'] = 3

df.employment_status = df.employment_status.astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#hhs_geo_region
df.hhs_geo_region[df.hhs_geo_region == 'atmpeygn'] = 1
df.hhs_geo_region[df.hhs_geo_region == 'bhuqouqj'] = 2
df.hhs_geo_region[df.hhs_geo_region == 'dqpwygqj'] = 3
df.hhs_geo_region[df.hhs_geo_region == 'fpwskwrf'] = 4
df.hhs_geo_region[df.hhs_geo_region == 'kbazzjca'] = 5
df.hhs_geo_region[df.hhs_geo_region == 'lrircsnp'] = 6
df.hhs_geo_region[df.hhs_geo_region == 'lzgpxyit'] = 7
df.hhs_geo_region[df.hhs_geo_region == 'mlyzmhmf'] = 8
df.hhs_geo_region[df.hhs_geo_region == 'oxchjgsf'] = 9
df.hhs_geo_region[df.hhs_geo_region == 'qufhixun'] = 10

df.hhs_geo_region = df.hhs_geo_region.astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#census_msa
df.census_msa[df.census_msa == 'MSA, Not Principle  City'] = 1
df.census_msa[df.census_msa == 'MSA, Principle City'] = 2
df.census_msa[df.census_msa == 'Non-MSA'] = 3

df.census_msa = df.census_msa.astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.dtypes
# Out:
# respondent_id                    int64
# h1n1_concern                   float64
# h1n1_knowledge                 float64
# behavioral_antiviral_meds      float64
# behavioral_avoidance           float64
# behavioral_face_mask           float64
# behavioral_wash_hands          float64
# behavioral_large_gatherings    float64
# behavioral_outside_home        float64
# behavioral_touch_face          float64
# doctor_recc_h1n1               float64
# doctor_recc_seasonal           float64
# chronic_med_condition          float64
# child_under_6_months           float64
# health_worker                  float64
# health_insurance               float64
# opinion_h1n1_vacc_effective    float64
# opinion_h1n1_risk              float64
# opinion_h1n1_sick_from_vacc    float64
# opinion_seas_vacc_effective    float64
# opinion_seas_risk              float64
# opinion_seas_sick_from_vacc    float64
# age_group                        int64
# education                        int64
# ...

# %% [markdown]
# ### Categorical Response Variable Exploration

# %% [markdown]
# #### age_group

# %% [markdown]
# ##### H1N1 Vaccine for Age Group

# %%
g = sns.catplot(x="age_group",y="h1n1_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("h1n1_vaccine")

# %%
g = sns.FacetGrid(df, col='h1n1_vaccine')
g = g.map(sns.histplot, "age_group", kde=True)

# %%
g = sns.kdeplot(df["age_group"][(df["h1n1_vaccine"] == 0) & (df["age_group"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["age_group"][(df["h1n1_vaccine"] == 1) & (df["age_group"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Age Group")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %% [markdown]
# ##### Seasonal Flu Vaccine for Age Group

# %%
g = sns.catplot(x="age_group",y="seasonal_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("seasonal_vaccine")

# %%
g = sns.FacetGrid(df, col='seasonal_vaccine')
g = g.map(sns.histplot, "age_group", kde=True)

# %%
g = sns.kdeplot(df["age_group"][(df["seasonal_vaccine"] == 0) & (df["age_group"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["age_group"][(df["seasonal_vaccine"] == 1) & (df["age_group"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Age Group")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %% [markdown]
# #### education

# %% [markdown]
# ##### H1N1 Vaccine for Education

# %%
g = sns.catplot(x="education",y="h1n1_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("h1n1_vaccine")

# %%
g = sns.FacetGrid(df, col='h1n1_vaccine')
g = g.map(sns.histplot, "education", kde=True)

# %%
g = sns.kdeplot(df["education"][(df["h1n1_vaccine"] == 0) & (df["education"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["education"][(df["h1n1_vaccine"] == 1) & (df["education"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Education")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %% [markdown]
# ##### Seasonal Flu Vaccine for Education

# %%
g = sns.catplot(x="education",y="seasonal_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("seasonal_vaccine")

# %%
g = sns.FacetGrid(df, col='seasonal_vaccine')
g = g.map(sns.histplot, "education", kde=True)

# %%
g = sns.kdeplot(df["education"][(df["seasonal_vaccine"] == 0) & (df["education"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["education"][(df["seasonal_vaccine"] == 1) & (df["education"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Education")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %% [markdown]
# #### race

# %% [markdown]
# ##### H1N1 Vaccine for Race

# %%
g = sns.catplot(x="race",y="h1n1_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("h1n1_vaccine")

# %%
g = sns.FacetGrid(df, col='h1n1_vaccine')
g = g.map(sns.histplot, "race", kde=True)

# %%
g = sns.kdeplot(df["race"][(df["h1n1_vaccine"] == 0) & (df["race"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["race"][(df["h1n1_vaccine"] == 1) & (df["race"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Race")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %% [markdown]
# ##### Seasonal Flu Vaccine for Race

# %%
g = sns.catplot(x="race",y="seasonal_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("seasonal_vaccine")

# %%
g = sns.FacetGrid(df, col='seasonal_vaccine')
g = g.map(sns.histplot, "race", kde=True)

# %%
g = sns.kdeplot(df["race"][(df["seasonal_vaccine"] == 0) & (df["race"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["race"][(df["seasonal_vaccine"] == 1) & (df["race"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Race")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %% [markdown]
# #### sex

# %% [markdown]
# ##### H1N1 Vaccine for Sex

# %%
g = sns.catplot(x="sex",y="h1n1_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("h1n1_vaccine")

# %%
g = sns.FacetGrid(df, col='h1n1_vaccine')
g = g.map(sns.histplot, "sex", kde=True)

# %%
g = sns.kdeplot(df["sex"][(df["h1n1_vaccine"] == 0) & (df["sex"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["sex"][(df["h1n1_vaccine"] == 1) & (df["sex"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Sex")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %% [markdown]
# ##### Seasonal Flu Vaccine for Sex

# %%
g = sns.catplot(x="sex",y="seasonal_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("seasonal_vaccine")

# %%
g = sns.FacetGrid(df, col='seasonal_vaccine')
g = g.map(sns.histplot, "sex", kde=True)

# %%
g = sns.kdeplot(df["sex"][(df["seasonal_vaccine"] == 0) & (df["sex"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["sex"][(df["seasonal_vaccine"] == 1) & (df["sex"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Sex")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %% [markdown]
# #### martial_status

# %% [markdown]
# ##### H1N1 Vaccine for Marital Status

# %%
g = sns.catplot(x="marital_status",y="h1n1_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("h1n1_vaccine")

# %%
g = sns.FacetGrid(df, col='h1n1_vaccine')
g = g.map(sns.histplot, "marital_status", kde=True)

# %%
g = sns.kdeplot(df["marital_status"][(df["h1n1_vaccine"] == 0) & (df["marital_status"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["marital_status"][(df["h1n1_vaccine"] == 1) & (df["marital_status"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Marital Status")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %% [markdown]
# ##### Seasonal Flu Vaccine for Marital Status

# %%
g = sns.catplot(x="marital_status",y="seasonal_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("seasonal_vaccine")

# %%
g = sns.FacetGrid(df, col='seasonal_vaccine')
g = g.map(sns.histplot, "marital_status", kde=True)

# %%
g = sns.kdeplot(df["marital_status"][(df["seasonal_vaccine"] == 0) & (df["marital_status"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["marital_status"][(df["seasonal_vaccine"] == 1) & (df["marital_status"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Marital Status")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %% [markdown]
# #### rent_or_own

# %% [markdown]
# ##### H1N1 Vaccine for Rent-or-Own

# %%
g = sns.catplot(x="rent_or_own",y="h1n1_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("h1n1_vaccine")

# %%
g = sns.FacetGrid(df, col='h1n1_vaccine')
g = g.map(sns.histplot, "rent_or_own", kde=True)

# %%
g = sns.kdeplot(df["rent_or_own"][(df["h1n1_vaccine"] == 0) & (df["rent_or_own"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["rent_or_own"][(df["h1n1_vaccine"] == 1) & (df["rent_or_own"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Rent-or-Own")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %% [markdown]
# ##### Seasonal Flu Vaccine for Rent-or-Own

# %%
g = sns.catplot(x="rent_or_own",y="seasonal_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("seasonal_vaccine")

# %%
g = sns.FacetGrid(df, col='seasonal_vaccine')
g = g.map(sns.histplot, "rent_or_own", kde=True)

# %%
g = sns.kdeplot(df["rent_or_own"][(df["seasonal_vaccine"] == 0) & (df["rent_or_own"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["rent_or_own"][(df["seasonal_vaccine"] == 1) & (df["rent_or_own"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Rent-or-Own")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %% [markdown]
# #### employment_status

# %% [markdown]
# ##### H1N1 Vaccine for Employment Status

# %%
g = sns.catplot(x="employment_status",y="h1n1_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("h1n1_vaccine")

# %%
g = sns.FacetGrid(df, col='h1n1_vaccine')
g = g.map(sns.histplot, "employment_status", kde=True)

# %%
g = sns.kdeplot(df["employment_status"][(df["h1n1_vaccine"] == 0) & (df["employment_status"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["employment_status"][(df["h1n1_vaccine"] == 1) & (df["employment_status"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Employment Status")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %% [markdown]
# ##### Seasonal Flu Vaccine for Employment Status

# %%
g = sns.catplot(x="employment_status",y="seasonal_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("seasonal_vaccine")

# %%
g = sns.FacetGrid(df, col='seasonal_vaccine')
g = g.map(sns.histplot, "employment_status", kde=True)

# %%
g = sns.kdeplot(df["employment_status"][(df["seasonal_vaccine"] == 0) & (df["employment_status"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["employment_status"][(df["seasonal_vaccine"] == 1) & (df["employment_status"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Employment Status")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %% [markdown]
# #### hhs_geo_region

# %% [markdown]
# ##### H1N1 Vaccine for HHS Geo Region

# %%
g = sns.catplot(x="hhs_geo_region",y="h1n1_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("h1n1_vaccine")

# %%
g = sns.FacetGrid(df, col='h1n1_vaccine')
g = g.map(sns.histplot, "hhs_geo_region", kde=True)

# %%
g = sns.kdeplot(df["hhs_geo_region"][(df["h1n1_vaccine"] == 0) & (df["hhs_geo_region"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["hhs_geo_region"][(df["h1n1_vaccine"] == 1) & (df["hhs_geo_region"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("HHS Geo Region")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %% [markdown]
# ##### Seasonal Flu Vaccine for HHS Geo Region

# %%
g = sns.catplot(x="hhs_geo_region",y="seasonal_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("seasonal_vaccine")

# %%
g = sns.FacetGrid(df, col='seasonal_vaccine')
g = g.map(sns.histplot, "hhs_geo_region", kde=True)

# %%
g = sns.kdeplot(df["hhs_geo_region"][(df["seasonal_vaccine"] == 0) & (df["hhs_geo_region"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["hhs_geo_region"][(df["seasonal_vaccine"] == 1) & (df["hhs_geo_region"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("HHS Geo Region")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %% [markdown]
# #### census_msa

# %% [markdown]
# ##### H1N1 Vaccine for Census MSA

# %%
g = sns.catplot(x="census_msa",y="h1n1_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("h1n1_vaccine")

# %%
g = sns.FacetGrid(df, col='h1n1_vaccine')
g = g.map(sns.histplot, "census_msa", kde=True)

# %%
g = sns.kdeplot(df["census_msa"][(df["h1n1_vaccine"] == 0) & (df["census_msa"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["census_msa"][(df["h1n1_vaccine"] == 1) & (df["census_msa"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Census MSA")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %% [markdown]
# ##### Seasonal Flu Vaccine for Census MSA

# %%
g = sns.catplot(x="census_msa",y="seasonal_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("seasonal_vaccine")

# %%
g = sns.FacetGrid(df, col='seasonal_vaccine')
g = g.map(sns.histplot, "census_msa", kde=True)

# %%
g = sns.kdeplot(df["census_msa"][(df["seasonal_vaccine"] == 0) & (df["census_msa"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["census_msa"][(df["seasonal_vaccine"] == 1) & (df["census_msa"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Census MSA")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %% [markdown]
# ### Outlier Detection

# %%
num_cols1= ['h1n1_concern',  'h1n1_knowledge', 'behavioral_antiviral_meds',  'behavioral_avoidance', 'behavioral_face_mask'] 

num_cols2= ['behavioral_wash_hands',  'behavioral_large_gatherings',  'behavioral_outside_home',  'behavioral_touch_face',  'doctor_recc_h1n1'] 

num_cols3= ['doctor_recc_seasonal', 'chronic_med_condition',  'child_under_6_months', 'health_worker',  'health_insurance'] 

num_cols4= ['opinion_h1n1_vacc_effective',  'opinion_h1n1_risk',  'opinion_h1n1_sick_from_vacc',  'opinion_seas_vacc_effective',  'opinion_seas_risk',  'opinion_seas_sick_from_vacc']

# %%
df.boxplot(num_cols1)

# %%
df.boxplot(num_cols2)

# %%
df.boxplot(num_cols3)

# %%
df.boxplot(num_cols4)

# %% [markdown]
# ### Feature Interaction

# %% [markdown]
# #####H1N1

# %%
g = sns.heatmap(df[["h1n1_vaccine","h1n1_concern","h1n1_knowledge","doctor_recc_h1n1","opinion_h1n1_vacc_effective","opinion_h1n1_risk","opinion_h1n1_sick_from_vacc"]].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %%
g = sns.catplot(x="doctor_recc_h1n1",y="h1n1_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("h1n1_vaccine")

# %%
g = sns.kdeplot(df["doctor_recc_h1n1"][(df["h1n1_vaccine"] == 0) & (df["doctor_recc_h1n1"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["doctor_recc_h1n1"][(df["h1n1_vaccine"] == 1) & (df["doctor_recc_h1n1"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Doctor Recommended")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %%
g = sns.catplot(x="opinion_h1n1_sick_from_vacc", y="h1n1_vaccine", hue="doctor_recc_h1n1", data=df,
                   height=6, kind="bar", palette="muted")
g.despine(left=True)
g = g.set_ylabels("vaccination probability")

# %%
g = sns.kdeplot(df["opinion_h1n1_sick_from_vacc"][(df["h1n1_vaccine"] == 0) & (df["doctor_recc_h1n1"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["opinion_h1n1_sick_from_vacc"][(df["h1n1_vaccine"] == 1) & (df["doctor_recc_h1n1"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Opinion - Sick from H1N1 Vaccine")
g.set_ylabel("Count")
g = g.legend(["No H1N1 Vaccine","H1N1 Vaccine"])

# %% [markdown]
# ######Behavioral Responses

# %%
g = sns.heatmap(df[["h1n1_vaccine","behavioral_antiviral_meds","behavioral_avoidance",
                    "behavioral_face_mask","behavioral_wash_hands",
                    "behavioral_large_gatherings","behavioral_outside_home",
                    "behavioral_touch_face"]].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %% [markdown]
# >>It appears that every single one of the questions involving behavior have a strong negative correlation to the probability for an individual to receive the vaccine.

# %% [markdown]
# ######Opinion Responses

# %%
g = sns.heatmap(df[["h1n1_vaccine","opinion_h1n1_vacc_effective","opinion_h1n1_risk",
                    "opinion_h1n1_sick_from_vacc","opinion_seas_vacc_effective",
                    "opinion_seas_risk","opinion_seas_sick_from_vacc"]].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %% [markdown]
# >> It appears that **opinion_seas_sick_from_vaccin**e and **opinion_h1n1_sick_from_vacc** both have a strong negative correlation to the H1N1 target variable.

# %% [markdown]
# ####Seasonal Flu Vaccine

# %%
g = sns.heatmap(df[["seasonal_vaccine","doctor_recc_seasonal","opinion_seas_vacc_effective","opinion_seas_risk","opinion_seas_sick_from_vacc"]].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %%
g = sns.catplot(x="doctor_recc_seasonal",y="seasonal_vaccine",data=df,kind="bar", height = 5 , 
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("seasonal_vaccine")

# %%
g = sns.kdeplot(df["doctor_recc_seasonal"][(df["seasonal_vaccine"] == 0) & (df["doctor_recc_seasonal"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["doctor_recc_seasonal"][(df["seasonal_vaccine"] == 1) & (df["doctor_recc_seasonal"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Doctor Recommended")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %%
g = sns.catplot(x="opinion_seas_sick_from_vacc", y="seasonal_vaccine", hue="doctor_recc_seasonal", data=df,
                   height=6, kind="bar", palette="muted")
g.despine(left=True)
g = g.set_ylabels("Seasonal Flu Vaccination Probability")

# %%
g = sns.kdeplot(df["opinion_seas_sick_from_vacc"][(df["seasonal_vaccine"] == 0) & (df["doctor_recc_seasonal"].notnull())], color="Red", shade = True)
g = sns.kdeplot(df["opinion_seas_sick_from_vacc"][(df["seasonal_vaccine"] == 1) & (df["doctor_recc_seasonal"].notnull())], ax =g, color="Blue", shade= True)
g.set_xlabel("Opinion - Sick from Seasonal Flu Vaccine")
g.set_ylabel("Count")
g = g.legend(["No Seasonal Flu Vaccine","Seasonal Flu Vaccine"])

# %% [markdown]
# ######Behavioral Responses

# %%
g = sns.heatmap(df[["seasonal_vaccine","behavioral_antiviral_meds","behavioral_avoidance",
                    "behavioral_face_mask","behavioral_wash_hands",
                    "behavioral_large_gatherings","behavioral_outside_home",
                    "behavioral_touch_face"]].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %% [markdown]
# ######Opinion Responses

# %%
g = sns.heatmap(df[["seasonal_vaccine","opinion_h1n1_vacc_effective","opinion_h1n1_risk",
                    "opinion_h1n1_sick_from_vacc","opinion_seas_vacc_effective",
                    "opinion_seas_risk","opinion_seas_sick_from_vacc"]].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %% [markdown]
# ### Feature Engineering - One Hot Encoding

# %%
df = pd.concat([df,pd.get_dummies(df['census_msa'], prefix='census_msa'),
                pd.get_dummies(df['age_group'], prefix='age'),
                pd.get_dummies(df['education'], prefix='education'),
                pd.get_dummies(df['race'], prefix='race'),
                pd.get_dummies(df['sex'], prefix='sex'),
                pd.get_dummies(df['marital_status'], prefix='marital_status'),
                pd.get_dummies(df['rent_or_own'], prefix='rent_or_own'),
                pd.get_dummies(df['hhs_geo_region'], prefix='hhs_geo_region')],axis=1)

df.drop(['census_msa'],axis=1, inplace=True)
df.drop(['age_group'],axis=1, inplace=True)
df.drop(['education'],axis=1, inplace=True)
df.drop(['race'],axis=1, inplace=True)
df.drop(['sex'],axis=1, inplace=True)
df.drop(['marital_status'],axis=1, inplace=True)
df.drop(['rent_or_own'],axis=1, inplace=True)
df.drop(['hhs_geo_region'],axis=1, inplace=True)

# %%
df.head()
# Out:
#    respondent_id  h1n1_concern  ...  hhs_geo_region_9  hhs_geo_region_10
# 0              0           1.0  ...                 1                  0
# 1              1           3.0  ...                 0                  0
# 2              2           1.0  ...                 0                  1
# 3              3           1.0  ...                 0                  0
# 4              4           2.0  ...                 0                  1
#
# [5 rows x 62 columns]

# %%
df.dtypes
# Out:
# respondent_id                  int64
# h1n1_concern                 float64
# h1n1_knowledge               float64
# behavioral_antiviral_meds    float64
# behavioral_avoidance         float64
#                               ...
# hhs_geo_region_6               uint8
# hhs_geo_region_7               uint8
# hhs_geo_region_8               uint8
# hhs_geo_region_9               uint8
# hhs_geo_region_10              uint8
# Length: 62, dtype: object

# %% [markdown]
# ##Modeling

# %%
#specify which variables to use 

df_use = df.drop(['health_insurance','income_poverty','employment_industry','employment_occupation'], axis=1)

# %% [markdown]
# ####Split Training Test Data

# %%
df_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26707 entries, 0 to 26706
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   respondent_id                26707 non-null  int64
#  1   h1n1_concern                 26707 non-null  float64
#  2   h1n1_knowledge               26707 non-null  float64
#  3   behavioral_antiviral_meds    26707 non-null  float64
#  4   behavioral_avoidance         26707 non-null  float64
#  5   behavioral_face_mask         26707 non-null  float64
#  6   behavioral_wash_hands        26707 non-null  float64
#  7   behavioral_large_gatherings  26707 non-null  float64
#  8   behavioral_outside_home      26707 non-null  float64
#  9   behavioral_touch_face        26707 non-null  float64
#  10  doctor_recc_h1n1             26707 non-null  float64
#  11  doctor_recc_seasonal         26707 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_transformer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.cluster import KMeans
from sklearn.ensemble import VotingClassifier
from sklearn import model_selection,linear_model, datasets
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
# splitting test and training (H1N1)

X1 = df_use.loc[:, ~df_use.columns.isin(['h1n1_vaccine', 'respondent_id'])]
y1 = df_use["h1n1_vaccine"]

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2)

# splitting test and training (Seasonal Flu)

X2 = df_use.loc[:, ~df_use.columns.isin(['seasonal_vaccine', 'respondent_id'])]
y2 = df_use["seasonal_vaccine"]

X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2)

#scaling
scaler = StandardScaler()  
scaler.fit(X1_train)

X1_train = scaler.transform(X1_train)
X1_test = scaler.transform(X1_test)
 
scaler.fit(X2_train)

X2_train = scaler.transform(X2_train)
X2_test = scaler.transform(X2_test)

# %% [markdown]
# ####Feature Selection - Lasso Regression

# %% [markdown]
# #####H1N1

# %%
sel_1 = SelectFromModel(LogisticRegression(C=1, penalty='l1',solver='liblinear'))
sel_1.fit(X1_train, y1_train)
# Out:
# SelectFromModel(estimator=LogisticRegression(C=1, class_weight=None, dual=False,
#                                              fit_intercept=True,
#                                              intercept_scaling=1, l1_ratio=None,
#                                              max_iter=100, multi_class='auto',
#                                              n_jobs=None, penalty='l1',
#                                              random_state=None,
#                                              solver='liblinear', tol=0.0001,
#                                              verbose=0, warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
sel_1.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True, False,  True, False,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False])

# %%
from sklearn.impute import SimpleImputer

# Imputation
my_imputer1 = SimpleImputer()
imputed_X1 = pd.DataFrame(my_imputer1.fit_transform(X1_train))

# Imputation removed column names; put them back
imputed_X1.columns = X1.columns

selected_feat1= imputed_X1.columns[(sel1.get_support())]
print('total features: {}'.format((X1_train.shape[1])))
print('selected features: {}'.format(len(selected_feat1)))

len(selected_feat1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-6ed0ad344ae1> in <module>()
#       8 imputed_X1.columns = X1.columns
#       9
# ---> 10 selected_feat1= imputed_X1.columns[(sel1.get_support())]
#      11 print('total features: {}'.format((X1_train.shape[1])))
#      12 print('selected features: {}'.format(len(selected_feat1)))
#
# NameError: name 'sel1' is not defined

# %%
print(selected_feat1)

# %% [markdown]
# #####Seasonal Flu

# %%
sel_2 = SelectFromModel(LogisticRegression(C=1, penalty='l1',solver='liblinear'))
sel_2.fit(X2_train, y2_train)

# %%
sel_2.get_support()

# %%
from sklearn.impute import SimpleImputer

# Imputation
my_imputer2 = SimpleImputer()
imputed_X2 = pd.DataFrame(my_imputer2.fit_transform(X2_train))

# Imputation removed column names; put them back
imputed_X2.columns = X2.columns

selected_feat2= imputed_X2.columns[(sel2.get_support())]
print('total features: {}'.format((X2_train.shape[1])))
print('selected features: {}'.format(len(selected_feat2)))
print('features with coefficients shrank to zero: {}'.format(np.sum(sel_2.estimator_.coef_ == 0)))

len(selected_feat2)

# %%
print(selected_feat1)

# %% [markdown]
# ####Feature Specification

# %%
X1_train_sel = sel_1.transform(X1_train)
X1_test_sel = sel_1.transform(X1_test)

X2_train_sel = sel_2.transform(X2_train)
X2_test_sel = sel_2.transform(X2_test)

# %%
X1_train_sel.shape, X1_test_sel.shape

# %%
X1_train.shape, X1_test.shape

# %%
X2_train_sel.shape, X2_test_sel.shape

# %%
X2_train.shape, X2_test.shape

# %% [markdown]
# ###Modeling - *H1N1*

# %% [markdown]
# ####Logistic Regression

# %%
# Logistic Regression
lr = LogisticRegression()

lrfit = lr.fit(X1_train_sel, y1_train)

y_pred = lr.predict(X1_test_sel)

print('Accuracy %.2f' % lr.score(X1_test_sel, y1_test))
print('Precision: %.3f' % precision_score(y_true=y1_test, y_pred=y_pred))
print('Recall: %.3f' % recall_score(y_true=y1_test, y_pred=y_pred))
print('F1: %.3f' % f1_score(y_true=y1_test, y_pred=y_pred))
print('Misclassified samples: %d' % (y1_test != y_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y1_test, lrfit.predict_proba(X1_test_sel)[:, 1]))

# %% [markdown]
# ####K-Nearest Neighbors

# %%
#K Nearest Neighbors
knn = KNeighborsClassifier(n_neighbors=10)
kfit = knn.fit(X1_train_sel,y1_train)

knn_y1_pred = knn.predict(X1_test_sel)

print('Accuracy %.2f' % knn.score(X1_test_sel, y1_test))
print('Precision: %.3f' % precision_score(y_true=y1_test, y_pred=knn_y1_pred))
print('Recall: %.3f' % recall_score(y_true=y1_test, y_pred=knn_y1_pred))
print('F1: %.3f' % f1_score(y_true=y1_test, y_pred=knn_y1_pred))
print('Misclassified samples: %d' % (y1_test != knn_y1_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y1_test, kfit.predict_proba(X1_test_sel)[:, 1]))

# %% [markdown]
# ####Gradient Boosting

# %%
#Gradient Boosting

gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
                                 max_depth=1, random_state=0).fit(X1_train_sel, y1_train)

gbc_y_pred = gbc.predict(X1_test_sel)

print('Accuracy %.2f' % gbc.score(X1_test_sel, y1_test))
print('Precision: %.3f' % precision_score(y_true=y1_test, y_pred=gbc_y_pred))
print('Recall: %.3f' % recall_score(y_true=y1_test, y_pred=gbc_y_pred))
print('F1: %.3f' % f1_score(y_true=y1_test, y_pred=gbc_y_pred))
print('Misclassified samples: %d' % (y1_test != gbc_y_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y1_test, gbc.predict_proba(X1_test_sel)[:, 1]))

# %% [markdown]
# ####Decision Tree

# %%
#Decision Tree

dt = DecisionTreeClassifier(max_depth=10, random_state=123)
dtfit = dt.fit(X1_train_sel, y1_train)

dt_y_pred = dt.predict(X1_test_sel)

print('Accuracy %.2f' % dt.score(X1_test_sel, y1_test))
print('Precision: %.3f' % precision_score(y_true=y1_test, y_pred=dt_y_pred))
print('Recall: %.3f' % recall_score(y_true=y1_test, y_pred=dt_y_pred))
print('F1: %.3f' % f1_score(y_true=y1_test, y_pred=dt_y_pred))
print('Misclassified samples: %d' % (y1_test != dt_y_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y1_test, dtfit.predict_proba(X1_test_sel)[:, 1]))

# %%
#instead of just doing the tree, trying to find the right parameters. 

param_dist = {"max_depth": [1,2,3,4,5,6,7,8,9],
             
              "max_features": [1,2,3,4,5,6,7,8,9],
              "min_samples_leaf": [1,2,3,4,5,6,7,8,9],
              "criterion": ["gini", "entropy"]}

tree = DecisionTreeClassifier()

# RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(tree, param_distributions=param_dist, cv=10, n_iter=100, random_state=0)

# Fit it to the data
tree_cv.fit(X1_train_sel, y1_train)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))

# %%
#Using the tuned decision tree parameters

dt2 = DecisionTreeClassifier(criterion= 'gini', max_depth= 6, 
                                     max_features= 9, min_samples_leaf= 1, 
                                     random_state=123)
dt2fit = dt2.fit(X1_train_sel, y1_train)
dt_y_pred2 = dt2.predict(X1_test_sel)

print()
print('Accuracy %.2f' % dt2.score(X1_test_sel, y1_test))
print('Precision: %.3f' % precision_score(y_true=y1_test, y_pred=dt_y_pred2))
print('Recall: %.3f' % recall_score(y_true=y1_test, y_pred=dt_y_pred2))
print('F1: %.3f' % f1_score(y_true=y1_test, y_pred=dt_y_pred2))
print('Misclassified samples: %d' % (y1_test != dt_y_pred2).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y1_test, dt2fit.predict_proba(X1_test_sel)[:, 1]))

# %% [markdown]
# ####Random Forest

# %%
#Random Forest

rf=RandomForestClassifier(n_estimators=1000)

rfit = rf.fit(X1_train_sel,y1_train)

rf_y_pred = rf.predict(X1_test_sel)

print('Accuracy %.2f' % rf.score(X1_test_sel, y1_test))
print('Precision: %.3f' % precision_score(y_true=y1_test, y_pred=rf_y_pred))
print('Recall: %.3f' % recall_score(y_true=y1_test, y_pred=rf_y_pred))
print('F1: %.3f' % f1_score(y_true=y1_test, y_pred=rf_y_pred))
print('Misclassified samples: %d' % (y1_test != rf_y_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y1_test, rfit.predict_proba(X1_test_sel)[:, 1]))

# %%
#Random Forest with Cross Validation
param_dist = {
               "max_depth": [int(x) for x in np.linspace(1, 19, num = 10)],
               "min_samples_leaf": [1, 2, 4, 6],
               }

rf = RandomForestClassifier()

rf_cv = RandomizedSearchCV(rf, param_distributions = param_dist, 
                           cv = 5, scoring='roc_auc',random_state=123, n_jobs = -1)

rfcvfit = rf_cv.fit(X1_train_sel, y1_train)
rf_y_pred = rf_cv.predict(X1_test_sel)

# Print the tuned parameters and score
print("Tuned Random Forest Parameters: {}".format(rfcvfit.best_params_))

# %%
rf1 = RandomForestClassifier(min_samples_leaf= 4,
                            max_depth= 19, random_state=123)

rf_cv1 = RandomizedSearchCV(rf1, param_distributions = param_dist, 
                           cv = 10, scoring='roc_auc',random_state=123, n_jobs = -1)

rfcv1fit = rf_cv1.fit(X1_train_sel, y1_train)
rf_y_pred = rf_cv1.predict(X1_test_sel)

print('Accuracy %.2f' % rf_cv1.score(X1_test_sel, y1_test))
print('Precision: %.3f' % precision_score(y_true=y1_test, y_pred=rf_y_pred))
print('Recall: %.3f' % recall_score(y_true=y1_test, y_pred=rf_y_pred))
print('F1: %.3f' % f1_score(y_true=y1_test, y_pred=rf_y_pred))
print('Misclassified samples: %d' % (y1_test != rf_y_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y1_test, rfcv1fit.predict_proba(X1_test_sel)[:, 1]))

# %% [markdown]
# ####Voting Classifier Ensemble Modeling

# %%
kfold_vc = model_selection.KFold(n_splits=10, random_state=10, shuffle=True)

estimators = []
mod_lr = LogisticRegression()
estimators.append(('logistic', mod_lr))
mod_knn = KNeighborsClassifier()
estimators.append(('knn', mod_knn))
mod_gbc = GradientBoostingClassifier()
estimators.append(('gbc', mod_gbc))
mod_rf = RandomForestClassifier()
estimators.append(('rf', mod_rf))
mod_rfcv = RandomForestClassifier(min_samples_leaf= 4,
                            max_depth= 19, random_state=123)
estimators.append(('rfcv', mod_rfcv))
mod_dt = DecisionTreeClassifier(max_depth=10, random_state=123)
estimators.append(('dt', mod_dt))
mod_dt2 = DecisionTreeClassifier(criterion= 'gini', max_depth= 6, 
                                     max_features= 9, min_samples_leaf= 1, 
                                     random_state=123)
estimators.append(('dt2', mod_dt2))

ensemble = VotingClassifier(estimators)
vc_roc_score = cross_val_score(ensemble, X1_train_sel, y1_train,cv=kfold_vc)
results_vc = model_selection.cross_val_score(ensemble, X1_train_sel, y1_train,cv=kfold_vc)

vc = VotingClassifier(estimators).fit(X1_train_sel, y1_train)

vc_y_pred = vc.predict(X1_test_sel)

print('Accuracy %.2f' % vc.score(X1_test_sel, y1_test))
print('Precision: %.3f' % precision_score(y_true=y1_test, y_pred=vc_y_pred))
print('Recall: %.3f' % recall_score(y_true=y1_test, y_pred=vc_y_pred))
print('F1: %.3f' % f1_score(y_true=y1_test, y_pred=vc_y_pred))
print('Misclassified samples: %d' % (y1_test != vc_y_pred).sum())
print('ROC/AUC Score: %.3f'%np.mean(vc_roc_score))

# %% [markdown]
# ###Modeling - *Seasonal Flu*

# %% [markdown]
# ####Logistic Regression

# %%
# Logistic Regression
lr = LogisticRegression()

lrfit = lr.fit(X2_train_sel, y2_train)

y_pred = lr.predict(X2_test_sel)

print('Accuracy %.2f' % lr.score(X2_test_sel, y2_test))
print('Precision: %.3f' % precision_score(y_true=y2_test, y_pred=y_pred))
print('Recall: %.3f' % recall_score(y_true=y2_test, y_pred=y_pred))
print('F1: %.3f' % f1_score(y_true=y2_test, y_pred=y_pred))
print('Misclassified samples: %d' % (y2_test != y_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y2_test, lrfit.predict_proba(X2_test_sel)[:, 1]))

# %% [markdown]
# ####K-Nearest Neighbors

# %%
#K Nearest Neighbors
knn = KNeighborsClassifier(n_neighbors=10)
kfit = knn.fit(X2_train_sel,y2_train)

knn_y2_pred = knn.predict(X2_test_sel)

print('Accuracy %.2f' % knn.score(X2_test_sel, y2_test))
print('Precision: %.3f' % precision_score(y_true=y2_test, y_pred=knn_y2_pred))
print('Recall: %.3f' % recall_score(y_true=y2_test, y_pred=knn_y2_pred))
print('F1: %.3f' % f1_score(y_true=y2_test, y_pred=knn_y2_pred))
print('Misclassified samples: %d' % (y2_test != knn_y2_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y2_test, kfit.predict_proba(X2_test_sel)[:, 1]))

# %% [markdown]
# ####Gradient Boosting

# %%
#Gradient Boosting

gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
                                 max_depth=1, random_state=0).fit(X2_train_sel, y2_train)

gbc_y_pred = gbc.predict(X2_test_sel)

print('Accuracy %.2f' % gbc.score(X2_test_sel, y2_test))
print('Precision: %.3f' % precision_score(y_true=y2_test, y_pred=gbc_y_pred))
print('Recall: %.3f' % recall_score(y_true=y2_test, y_pred=gbc_y_pred))
print('F1: %.3f' % f1_score(y_true=y2_test, y_pred=gbc_y_pred))
print('Misclassified samples: %d' % (y2_test != gbc_y_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y2_test, gbc.predict_proba(X2_test_sel)[:, 1]))

# %% [markdown]
# ####Decision Tree

# %%
#Decision Tree

dt = DecisionTreeClassifier(max_depth=10, random_state = 123)
dtfit = dt.fit(X2_train_sel, y2_train)

dt_y_pred = dt.predict(X2_test_sel)

print('Accuracy %.2f' % dt.score(X2_test_sel, y2_test))
print('Precision: %.3f' % precision_score(y_true=y2_test, y_pred=dt_y_pred))
print('Recall: %.3f' % recall_score(y_true=y2_test, y_pred=dt_y_pred))
print('F1: %.3f' % f1_score(y_true=y2_test, y_pred=dt_y_pred))
print('Misclassified samples: %d' % (y2_test != dt_y_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y2_test, dtfit.predict_proba(X2_test_sel)[:, 1]))

# %%
#instead of just doing the tree, trying to find the right parameters. 

param_dist = {"max_depth": [1,2,3,4,5,6,7,8,9],
             
              "max_features": [1,2,3,4,5,6,7,8,9],
              "min_samples_leaf": [1,2,3,4,5,6,7,8,9],
              "criterion": ["gini", "entropy"]}

tree = DecisionTreeClassifier()

# RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(tree, param_distributions=param_dist, cv=10, n_iter=100, random_state=123)

# Fit it to the data
tree_cv.fit(X2_train_sel, y2_train)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))

# %%
#Using the tuned decision tree parameters

dt2 = DecisionTreeClassifier(criterion= 'gini', max_depth= 9, 
                                     max_features= 9, min_samples_leaf= 9,random_state = 123)
dt2fit = dt2.fit(X2_train_sel, y2_train)
dt_y_pred2 = dt2.predict(X2_test_sel)

print()
print('Accuracy %.2f' % dt2.score(X2_test_sel, y2_test))
print('Precision: %.3f' % precision_score(y_true=y2_test, y_pred=dt_y_pred2))
print('Recall: %.3f' % recall_score(y_true=y2_test, y_pred=dt_y_pred2))
print('F1: %.3f' % f1_score(y_true=y2_test, y_pred=dt_y_pred2))
print('Misclassified samples: %d' % (y2_test != dt_y_pred2).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y2_test, dt2fit.predict_proba(X2_test_sel)[:, 1]))

# %% [markdown]
# ####Random Forest

# %%
#Random Forest

rf=RandomForestClassifier(n_estimators=1000)

rffit = rf.fit(X2_train_sel,y2_train)

rf_y_pred = rf.predict(X2_test_sel)

print('Accuracy %.2f' % rf.score(X2_test_sel, y2_test))
print('Precision: %.3f' % precision_score(y_true=y2_test, y_pred=rf_y_pred))
print('Recall: %.3f' % recall_score(y_true=y2_test, y_pred=rf_y_pred))
print('F1: %.3f' % f1_score(y_true=y2_test, y_pred=rf_y_pred))
print('Misclassified samples: %d' % (y2_test != rf_y_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y2_test, rffit.predict_proba(X2_test_sel)[:, 1]))

# %%
#Random Forest with Cross Validation
param_dist = {
               "max_depth": [int(x) for x in np.linspace(1, 19, num = 10)],
               "min_samples_leaf": [1, 2, 4, 6],
               }

rf = RandomForestClassifier()

rf_cv = RandomizedSearchCV(rf, param_distributions = param_dist, 
                           cv = 10, scoring='roc_auc',random_state=123, n_jobs = -1)

rfcvfit = rf_cv.fit(X2_train_sel, y2_train)
rf_y_pred = rf_cv.predict(X2_test_sel)

# Print the tuned parameters and score
print("Tuned Random Forest Parameters: {}".format(rfcvfit.best_params_))

# %%
rf2 = RandomForestClassifier(min_samples_leaf= 4, 
                            max_depth= 19, random_state=123)

rf_cv2 = RandomizedSearchCV(rf2, param_distributions = param_dist, 
                           cv = 10, scoring='roc_auc',random_state=123, n_jobs = -1)

rfcv2fit = rf_cv2.fit(X2_train_sel, y2_train)
rf_y_pred = rf_cv2.predict(X2_test_sel)

print('Accuracy %.2f' % rf_cv2.score(X2_test_sel, y2_test))
print('Precision: %.3f' % precision_score(y_true=y2_test, y_pred=rf_y_pred))
print('Recall: %.3f' % recall_score(y_true=y2_test, y_pred=rf_y_pred))
print('F1: %.3f' % f1_score(y_true=y2_test, y_pred=rf_y_pred))
print('Misclassified samples: %d' % (y2_test != rf_y_pred).sum())
print('ROC/AUC Score: %.3f'% roc_auc_score(y2_test, rfcv2fit.predict_proba(X2_test_sel)[:, 1]))

# %% [markdown]
# ####Voting Classifier Ensemble Modeling

# %%
kfold_vc = model_selection.KFold(n_splits=10, random_state=10,shuffle=True)

estimators = []
mod_lr = LogisticRegression()
estimators.append(('logistic', mod_lr))
mod_knn = KNeighborsClassifier()
estimators.append(('knn', mod_knn))
mod_rf = RandomForestClassifier()
estimators.append(('rf', mod_rf))
mod_rfcv = RandomForestClassifier(min_samples_leaf= 4, 
                            max_depth= 19, random_state=123)
estimators.append(('rfcv', mod_rfcv))
mod_gbc = GradientBoostingClassifier()
estimators.append(('gbc', mod_gbc))
mod_dt = DecisionTreeClassifier(max_depth=10, random_state=123)
estimators.append(('dt', mod_dt))
mod_dt2 = DecisionTreeClassifier(criterion= 'gini', max_depth= 8, 
                                     max_features= 8, min_samples_leaf= 3, 
                                     random_state=123)
estimators.append(('dt2', mod_dt2))

ensemble = VotingClassifier(estimators)
vc_roc_score = cross_val_score(ensemble, X2_train_sel, y2_train,cv=kfold_vc)
results_vc = model_selection.cross_val_score(ensemble, X2_train_sel, y2_train, cv=kfold_vc)

vc = VotingClassifier(estimators).fit(X2_train_sel, y2_train)

vc_y_pred = vc.predict(X2_test_sel)

print('Accuracy %.2f' % vc.score(X2_test_sel, y2_test))
print('Precision: %.3f' % precision_score(y_true=y2_test, y_pred=vc_y_pred))
print('Recall: %.3f' % recall_score(y_true=y2_test, y_pred=vc_y_pred))
print('F1: %.3f' % f1_score(y_true=y2_test, y_pred=vc_y_pred))
print('Misclassified samples: %d' % (y2_test != vc_y_pred).sum())
print('ROC/AUC Score: %.3f'%np.mean(vc_roc_score))

# %% [markdown]
# ##Conclusion - Best Model

# %% [markdown]
# I have chosen to look at the Accuracy, Precision, Recall, Misclassified Samples, and the ROC/AUC scores to determine the best models for each H1N1 Vaccine and Seasonal Flu Vaccine prediction.
#
# Especially for the H1N1 Vaccine variable, I will rely heavily on the ROC/AUC score as our metric for prediction because it levels out the curve for unbalanced data. When I explored the counts in the data set for the h1n1_vaccine, I discovered that there were nearly four times as many people who refused the H1N1 vaccine as received it.
#
# Surprisingly, the ensemble modeling did not produce a model with better performance than some of the individual models, though I am concerned about overfitting for real life application scenarios.

# %% [markdown]
# ###H1N1 Vaccine

# %% [markdown]
# While the Logistic Regression model had high accuracy, precision, recall, and ROC/AUC scores, Gradient Boosting seemed to be an equally robust model, as all of the metrics were nearly equal to those of Logistic Regression. After all models were assessed, I have decided that the Decision Tree (original) model is the best for predicting whether a respondent is likely to receive the H1N1 Vaccine.The metrics were all comparable to those of the Logistic Regression and Gradient Boosting models, but the ROC/AUC score for the Decision Tree is 0.924.

# %% [markdown]
# ###Seasonal Flu Vaccine

# %% [markdown]
# While the Logistic Regression model had high accuracy, precision, recall, and ROC/AUC scores, Gradient Boosting seemed to be an equally robust model, as all of the metrics were nearly equal to those of Logistic Regression. Despite this, the Random Forest model using GridSearchCV had slightly better results in all of the assessment metrics. For this reason, I have decided that the Random Forest (CV) model is the best for predicting whether a respondent is likely to receive the Seasonal Flu Vaccine.
